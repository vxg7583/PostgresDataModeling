# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 50;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [(0, 1543449657796, 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"""Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"""'),
#  (1, 1543449690796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (2, 1543449841796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (3, 1543449895796, 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"""Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"""'),
#  (4, 1543450033796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (5, 1543450256796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (6, 1543450264796, 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"""Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"""'),
#  (7, 1543450450796, 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"""Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"""'),
#  (8, 1543450562796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (9, 1543450691796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (10, 1543450933796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (11, 1543451175796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (12, 1543451453796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (13, 1543451707796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (14, 1543452014796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (15, 1543452253796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (16, 1543452394796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (17, 1543452588796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (18, 1543453030796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (19, 1543453332796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (20, 1543453596796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (21, 1543453763796, 50, 'free', None, None, 1011, 'New Haven-Milford, CT', '"""Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"""'),
#  (22, 1543453798796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (23, 1543454037796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (24, 1543454254796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (25, 1543454533796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (26, 1543454778796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (27, 1543455073796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (28, 1543455218796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (29, 1543455510796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (30, 1543455747796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (32, 1543456010796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (33, 1543456346796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (34, 1543456517796, 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (35, 1543458271796, 54, 'free', None, None, 951, 'Yuba City, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (36, 1543458485796, 54, 'free', None, None, 951, 'Yuba City, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (37, 1543458671796, 54, 'free', None, None, 951, 'Yuba City, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (38, 1543458973796, 54, 'free', None, None, 951, 'Yuba City, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (39, 1543459210796, 54, 'free', None, None, 951, 'Yuba City, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (40, 1543460277796, 32, 'free', None, None, 1045, 'New York-Newark-Jersey City, NY-NJ-PA', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (41, 1543460442796, 32, 'free', None, None, 1045, 'New York-Newark-Jersey City, NY-NJ-PA', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (42, 1543460835796, 4, 'free', None, None, 587, 'Parkersburg-Vienna, WV', '"""Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"""'),
#  (44, 1543465636796, 52, 'free', None, None, 990, 'Houston-The Woodlands-Sugar Land, TX', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (45, 1543465913796, 52, 'free', None, None, 990, 'Houston-The Woodlands-Sugar Land, TX', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (46, 1543467355796, 14, 'free', None, None, 1038, 'Red Bluff, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (47, 1543467608796, 14, 'free', None, None, 1038, 'Red Bluff, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (48, 1543479522796, 98, 'free', None, None, 865, 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '"""Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"""'),
#  (49, 1543479789796, 98, 'free', None, None, 865, 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '"""Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"""'),
#  (51, 1543489167796, 101, 'free', None, None, 1016, 'New Orleans-Metairie, LA', '"""Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"""'),
#  (52, 1543489392796, 101, 'free', None, None, 1016, 'New Orleans-Metairie, LA', '"""Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"""')]

# %%
# %sql SELECT * FROM users LIMIT 50;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [(73, 'Jacob', 'Klein', 'M', 'paid'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (14, 'Theodore', 'Harris', 'M', 'free'),
#  (98, 'Jordyn', 'Powell', 'F', 'free'),
#  (78, 'Chloe', 'Roth', 'F', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (52, 'Theodore', 'Smith', 'M', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (79, 'James', 'Martin', 'M', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (4, 'Alivia', 'Terrell', 'F', 'free'),
#  (39, 'Walter', 'Frye', 'M', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (82, 'Avery', 'Martinez', 'F', 'paid'),
#  (16, 'Rylan', 'George', 'M', 'paid'),
#  (55, 'Martin', 'Johnson', 'M', 'free'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'paid'),
#  (9, 'Wyatt', 'Scott', 'M', 'free'),
#  (22, 'Sean', 'Wilson', 'F', 'free'),
#  (74, 'Braden', 'Parker', 'M', 'free'),
#  (80, 'Tegan', 'Levine', 'F', 'paid'),
#  (89, 'Kynnedi', 'Sanchez', 'F', 'free'),
#  (38, 'Gianna', 'Jones', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (66, 'Kevin', 'Arellano', 'M', 'free'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (52, 'Theodore', 'Smith', 'M', 'free'),
#  (5, 'Elijah', 'Davis', 'M', 'free'),
#  (16, 'Rylan', 'George', 'M', 'paid'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'paid'),
#  (28, 'Brantley', 'West', 'M', 'free'),
#  (77, 'Magdalene', 'Herman', 'F', 'free'),
#  (55, 'Martin', 'Johnson', 'M', 'free'),
#  (36, 'Matthew', 'Jones', 'M', 'paid'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'paid'),
#  (37, 'Jordan', 'Hicks', 'F', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (80, 'Tegan', 'Levine', 'F', 'paid'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 50;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 149.86404),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 75.67628),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 290.55955),
#  ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305.162),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282.43546),
#  ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, 197.19791),
#  ('SODAUVL12A8C13D184', 'Prognosis', 'ARWB3G61187FB49404', 2000, 363.85914),
#  ('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 335.51628),
#  ('SOLYIBD12A8C135045', 'Music is what we love', 'AR051KA1187B98B2FF', 0, 261.51138),
#  ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 'AR9AWNF1187B9AB0B4', 0, 236.93016),
#  ('SOTTDKS12AB018D69B', 'It Wont Be Christmas', 'ARMBR4Y1187B9990EB', 0, 241.47546),
#  ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 124.86485),
#  ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, 186.48771),
#  ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, 173.66159),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225.09669),
#  ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 164.80608),
#  ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133.32853),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156.39465),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 342.56934),
#  ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, 313.12934),
#  ('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, 484.62322),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168.25424),
#  ('SOZQDIU12A58A7BCF6', 'Superconfidential', 'ARNTLGG11E2835DDB9', 0, 338.31138),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 269.58322),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 207.77751)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('AR8IEZO1187B99055E', 'Marc Shaiman', '', None, None),
#  ('AR558FS1187FB45658', '40 Grit', '', None, None),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', None, None),
#  ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', '40.79086', '-73.96644'),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', '-13.442', '-41.9952')]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 29, 0, 0, 57, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 1, 30, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 4, 1, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 4, 55, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 7, 13, 796000), 0, 29, 48, 11, 2018, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
